# %%
# Analisando um cliente
# Decidir qual é o status do Score de Crédito do cliente (Good, Standard, Poor)

# %%
# Passo a passo do projeto
#   0: Entender o desafio da empresa
#   1: Importar a base de dados
import pandas as pd

table = pd.read_csv("clients.csv")
display(table)
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
#   2: Tratar e preparar a base de dados para a inteligência artificial
#   3: Criar o modelo de previsão/modelo de IA
#   4: Avaliar e escolher o melhor modelo
#   5: Realizar novas previsões por meio do modelo
